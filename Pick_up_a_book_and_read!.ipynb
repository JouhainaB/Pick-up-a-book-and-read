# %% [markdown]
# <a href="https://colab.research.google.com/github/JouhainaB/Pick-up-a-book-and-read/blob/main/Pick_up_a_book_and_read!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('/content/Books and HICP pivoted.xlsx')
df
# Out:
#               Table 1     Unnamed: 1  Unnamed: 2          Unnamed: 3
# 0            Category        Country  Year Month  Index (2015 = 100)
# 1      All-items HICP        Austria     2000M01               74.28
# 2      All-items HICP        Austria     2000M02               74.85
# 3      All-items HICP        Austria     2000M03               74.92
# 4      All-items HICP        Austria     2000M04               74.78
# ...               ...            ...         ...                 ...
# 17852           Books  United States     2020M04                 NaN
# 17853           Books  United States     2020M05                 NaN
# 17854           Books  United States     2020M06                 NaN
# 17855           Books  United States     2020M07                 NaN
# 17856           Books  United States     2020M08                 NaN
#
# [17857 rows x 4 columns]

# %%
df.columns = df.iloc[0]
df=df[1:]
df
# Out:
# 0            Category        Country Year Month Index (2015 = 100)
# 1      All-items HICP        Austria    2000M01              74.28
# 2      All-items HICP        Austria    2000M02              74.85
# 3      All-items HICP        Austria    2000M03              74.92
# 4      All-items HICP        Austria    2000M04              74.78
# 5      All-items HICP        Austria    2000M05              74.71
# ...               ...            ...        ...                ...
# 17852           Books  United States    2020M04                NaN
# 17853           Books  United States    2020M05                NaN
# 17854           Books  United States    2020M06                NaN
# 17855           Books  United States    2020M07                NaN
# 17856           Books  United States    2020M08                NaN
#
# [17856 rows x 4 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# 0
# Category                0
# Country                 0
# Year Month              0
# Index (2015 = 100)    693
# dtype: int64

# %%
df.dropna(subset=['Index (2015 = 100)'],inplace=True)
# Out:
# <ipython-input-15-c4673442fecb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['Index (2015 = 100)'],inplace=True)

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df,x='Country',y='Index (2015 = 100)')
plt.xticks(rotation=90)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Index',fontsize=15)
plt.title('Country vs Index ',fontsize=16)
plt.grid()

# %%
sns.histplot(data=df,x='Index (2015 = 100)',y=None,stat='count',bins=30)
plt.xlabel('Index',fontsize=15)
plt.ylabel('count',fontsize=15)
plt.title('Distribution of Index (2015 = 100)',fontsize=16)
plt.show()
